# %%
# Import libraries
import pandas as pd
import networkx as nx

# Load the data
data = pd.read_excel("C:/Users/timot/Documents/Master data science for business and entrepreneurship/Social network analysis/BACRIM2020-DB.xlsx")
print(data.columns)
# Combine rows with the same 'grupo' by concatenating alliances and setting binary columns
data_combined = (
    data.groupby('grupo').agg({
        'estado': lambda x: ";".join(pd.Series(";".join(x.dropna()).split(";")).unique()), # Concatenate unique estados
        'aliados': lambda x: ";".join(pd.Series(";".join(x.dropna()).split(";")).unique()),  # Concatenate unique allies
        'rivales': lambda x: ";".join(pd.Series(";".join(x.dropna()).split(";")).unique()),  # Concatenate unique rivals
        'persona': lambda x: ";".join(x.dropna()),  # Concatenate persona information if it exists
        'número de rivales': lambda x: int(any(x == 1)),  # Binary column
        'actividades_delictivas': lambda x: int(any(x == 1)),
        'narcotrafico': lambda x: int(any(x == 1)),
        'conflictos_armados': lambda x: int(any(x == 1)),
        'presencia_noviolenta': lambda x: int(any(x == 1)),
        'accion_guber': lambda x: int(any(x == 1)),
        'otros': lambda x: int(any(x == 1))
    }).reset_index()
)


# Prepare edges (alliances and rivalries) with unique 'grupo' identifiers
edges = []
for i, row in data_combined.iterrows():
    cartel = row['grupo']
    
    # Process allies
    if pd.notna(row['aliados']):
        allies = row['aliados'].split(";")
        for ally in allies:
            edges.append({'from': cartel, 'to': ally, 'type': 'alliance'})
    
    # Process rivals
    if pd.notna(row['rivales']):
        rivals = row['rivales'].split(";")
        for rival in rivals:
            edges.append({'from': cartel, 'to': rival, 'type': 'rivalry'})

# Convert edges list to a DataFrame and remove duplicates
print(edges)
edges_df = pd.DataFrame(edges).drop_duplicates()
print(edges_df)

# Sort 'from' and 'to' columns lexicographically for each row so (A, B) and (B, A) are treated as the same
edges_df[['from_sorted', 'to_sorted']] = edges_df.apply(lambda x: sorted([x['from'], x['to']]), axis=1, result_type='expand')

# Drop duplicates based on the sorted columns ('from_sorted' and 'to_sorted') to ensure undirected edge uniqueness
valid_edges = edges_df.drop_duplicates(subset=['from_sorted', 'to_sorted'])

# Drop the sorting columns after deduplication to get back the original 'from' and 'to' structure
valid_edges = valid_edges[['from', 'to', 'type']]

# Filter edges to ensure 'from' and 'to' vertices exist in `data_combined`
valid_edges = valid_edges[
    valid_edges['from'].isin(data_combined['grupo']) &
    valid_edges['to'].isin(data_combined['grupo'])
]

# Export the valid_edges DataFrame to a CSV file
valid_edges.to_csv("valid_edges.csv", index=False)
data_combined.drop(columns = ["aliados", "rivales"]).to_csv("vertice_data.csv", index=False)
# Out:
# Index(['id', 'grupo', 'persona', 'estado', 'aliados', 'número de aliados',
#        'rivales', 'número de rivales', 'actividades_delictivas',
#        'narcotrafico', 'conflictos_armados', 'presencia_noviolenta',
#        'accion_guber', 'otros', 'fecha', 'link1', 'link2', 'link3', 'link4',
#        'link5', 'link6', 'link7', 'link8', 'link9', '...25', '...26'],
#       dtype='object')
# [{'from': 'ACME', 'to': 'Cártel Jalisco Nueva Generación (CJNG)', 'type': 'alliance'}, {'from': 'ACME', 'to': 'La Unión Tepito', 'type': 'alliance'}, {'from': 'ACME', 'to': 'Cártel de Tláhuac', 'type': 'alliance'}, {'from': 'ACME', 'to': '', 'type': 'rivalry'}, {'from': 'Banda de El Perro', 'to': '', 'type': 'alliance'}, {'from': 'Banda de El Perro', 'to': '', 'type': 'rivalry'}, {'from': 'CJNG Comando la Mancha', 'to': 'Cártel Jalisco Nueva Generación (CJNG)', 'type': 'alliance'}, {'from': 'CJNG Comando la Mancha', 'to': 'Cártel de Sinaloa', 'type': 'rivalry'}, {'from': 'Caballeros Templarios', 'to': 'La Nueva Familia Michoacana', 'type': 'alliance'}, {'from': 'Caballeros Templarios', 'to': 'Guerreros Unidos', 'type': 'rivalry'}, {'from': 'Comandante Coronavirus', 'to': '', 'type': 'alliance'}, {'from': 'Comandante Coronavirus', 'to': '', 'type': 'rivalry'}, {'from': 'Cártel Independiente de Acapulco', 'to': '', 'type': 'alliance'}, {'from': 'Cártel Independiente de Acapulco', 'to': '', 'type': 'rivalry'}, {'from': 'Cártel Jalisco Nueva Generación (CJNG)', 'to': 'CJNG Comando la Mancha', 'type': 'alliance'}, {'from': 'Cártel Jalisco Nueva Generación (CJNG)', 'to': 'Los Cabos', 'type': 'alliance'}, {'from': 'Cártel Jalisco Nueva Generación (CJNG)', 'to': 'ACME', 'type': 'alliance'}, {'from': 'Cártel Jalisco Nueva Generación (CJNG)', 'to': 'La Unión Tepito', 'type': 'alliance'}, {'from': 'Cártel Jalisco Nueva Generación (CJNG)', 'to': 'Cártel de Tláhuac', 'type': 'alliance'}, {'from': 'Cártel Jalisco Nueva Generación (CJNG)', 'to': 'Fuerza Anti-Unión Tepito', 'type': 'alliance'}, {'from': 'Cártel Jalisco Nueva Generación (CJNG)', 'to': 'U o la UVA', 'type': 'alliance'}, {'from': 'Cártel Jalisco Nueva Generación (CJNG)', 'to': 'La Anti-Unión o La Rosa Nueva', 'type': 'alliance'}, {'from': 'Cártel Jalisco Nueva Generación (CJNG)', 'to': 'Los Cuinis', 'type': 'alliance'}, {'from': 'Cártel Jalisco Nueva Generación (CJNG)', 'to': 'La Unión León', 'type': 'alliance'}, {'from': 'Cártel Jalisco Nueva Generación (CJNG)', 'to': 'Los Tlacos (Cartel de la Sierra)', 'type': 'alliance'}, {'from': 'Cártel Jalisco Nueva Generación (CJNG)', 'to': 'Cártel Zicuirán Nueva Generación', 'type': 'alliance'}, {'from': 'Cártel Jalisco Nueva Generación (CJNG)', 'to': 'Los Colombianos', 'type': 'alliance'}, {'from': 'Cártel Jalisco Nueva Generación (CJNG)', 'to': 'Los Metros', 'type': 'alliance'}, {'from': 'Cártel Jalisco Nueva Generación (CJNG)', 'to': 'Los Piña', 'type': 'alliance'}, {'from': 'Cártel Jalisco Nueva Generación (CJNG)', 'to': 'Cártel de Sinaloa', 'type': 'rivalry'}, {'from': 'Cártel Jalisco Nueva Generación (CJNG)', 'to': 'Cártel de Los Arellano Félix', 'type': 'rivalry'}, {'from': 'Cártel Jalisco Nueva Generación (CJNG)', 'to': 'La Nueva Familia Michoacana', 'type': 'rivalry'}, {'from': 'Cártel Jalisco Nueva Generación (CJNG)', 'to': 'La Unión Tepito', 'type': 'rivalry'}, {'from': 'Cártel Jalisco Nueva Generación (CJNG)', 'to': 'El Cano', 'type': 'rivalry'}, {'from': 'Cártel Jalisco Nueva Generación (CJNG)', 'to': 'Cártel de Tláhuac', 'type': 'rivalry'}, {'from': 'Cártel Jalisco Nueva Generación (CJNG)', 'to': 'Caballeros Templarios', 'type': 'rivalry'}, {'from': 'Cártel Jalisco Nueva Generación (CJNG)', 'to': 'La Barredora 24/7', 'type': 'rivalry'}, {'from': 'Cártel Jalisco Nueva Generación (CJNG)', 'to': 'Cártel de Santa Rosa de Lima', 'type': 'rivalry'}, {'from': 'Cártel Jalisco Nueva Generación (CJNG)', 'to': 'Cártel Nueva Plaza', 'type': 'rivalry'}, {'from': 'Cártel Jalisco Nueva Generación (CJNG)', 'to': 'Cárteles Unidos', 'type': 'rivalry'}, {'from': 'Cártel Jalisco Nueva Generación (CJNG)', 'to': 'Zetas Vieja Escuela', 'type': 'rivalry'}, {'from': 'Cártel Jalisco Nueva Generación (CJNG)', 'to': 'Los Mayas', 'type': 'rivalry'}, {'from': 'Cártel Jalisco Nueva Generación (CJNG)', 'to': 'Guerreros Unidos', 'type': 'rivalry'}, {'from': 'Cártel Jalisco Nueva Generación (CJNG)', 'to': 'Los Blancos de Troya', 'type': 'rivalry'}, {'from': ...
#                     from                                      to      type
# 0                   ACME  Cártel Jalisco Nueva Generación (CJNG)  alliance
# 1                   ACME                         La Unión Tepito  alliance
# 2                   ACME                       Cártel de Tláhuac  alliance
# 3                   ACME                                           rivalry
# 4      Banda de El Perro                                          alliance
# ..                   ...                                     ...       ...
# 408  Zetas Vieja Escuela                  Cártel de Los Alemanes  alliance
# 409  Zetas Vieja Escuela  Cártel Jalisco Nueva Generación (CJNG)   rivalry
# 410  Zetas Vieja Escuela                      Cártel del Noreste   rivalry
# 411  Zetas Vieja Escuela                        Cártel del Golfo   rivalry
# 412  Zetas Vieja Escuela                            Grupo Sombra   rivalry
#
# [413 rows x 3 columns]

# %%
import pandas as pd
import numpy as np

# Load the data
data = pd.read_excel("C:/Users/timot/Documents/Master data science for business and entrepreneurship/Social network analysis/BACRIM2020-DB.xlsx")

# Ensure the 'estado' column contains the states in a format that can be split
data['estado'] = data['estado'].fillna('')  # Fill any NaN with an empty string

# One-hot encode the 'estado' column for each unique group
# Assuming the delimiter is ';' - adjust if needed
states_expanded = data[['grupo', 'estado']].drop_duplicates()  # Keep only unique combinations
states_expanded = states_expanded.set_index('grupo')['estado'].str.get_dummies(sep=';')

# Combine one-hot encoded states with unique groups
data = states_expanded.groupby('grupo').max().reset_index()

# Isolate the state presence columns and cartel names
cartel_names = data['grupo']
state_data = data.drop(columns=['grupo'])

# Create an empty dependency matrix
dependency_matrix = np.zeros((len(cartel_names), len(cartel_names)), dtype=int)

# Compute the dependency matrix
for i in range(len(cartel_names)):
    for j in range(len(cartel_names)):
        # Check if there is any common state operation
        if (state_data.iloc[i] & state_data.iloc[j]).any():
            dependency_matrix[i, j] = 1

np.fill_diagonal(dependency_matrix, 0)

# Convert to a DataFrame for readability, with cartels as row and column labels
dependency_df = pd.DataFrame(dependency_matrix, index=cartel_names, columns=cartel_names)

# Save the result to an Excel file
output_path = 'state_dependency_matrix.csv'
dependency_df.to_csv(output_path, index=False)

print(f"File saved as '{output_path}'")
dependency_df
# Out:
# File saved as 'state_dependency_matrix.csv'
# grupo                                               ACME  Banda de El Perro  \
# grupo
# ACME                                                   0                  1
# Banda de El Perro                                      1                  0
# CJNG Comando la Mancha                                 0                  0
# Caballeros Templarios                                  1                  1
# Comandante Coronavirus                                 0                  0
# ...                                                  ...                ...
# Tláhuac-Barbas                                         1                  1
# Tropa del Infierno                                     0                  0
# U o la UVA                                             1                  1
# Unión de Pueblos y Organizaciones del Estado de...     0                  0
# Zetas Vieja Escuela                                    0                  0
#
# grupo                                               CJNG Comando la Mancha  \
# grupo
# ACME                                                                     0
# Banda de El Perro                                                        0
# CJNG Comando la Mancha                                                   0
# Caballeros Templarios                                                    0
# Comandante Coronavirus                                                   0
# ...                                                                    ...
# Tláhuac-Barbas                                                           0
# Tropa del Infierno                                                       0
# U o la UVA                                                               0
# Unión de Pueblos y Organizaciones del Estado de...                       0
# Zetas Vieja Escuela                                                      0
#
# grupo                                               Caballeros Templarios  \
# grupo
# ACME                                                                    1
# Banda de El Perro                                                       1
# CJNG Comando la Mancha                                                  0
# Caballeros Templarios                                                   0
# Comandante Coronavirus                                                  0
# ...                                                                   ...
# Tláhuac-Barbas                                                          1
# Tropa del Infierno                                                      0
# U o la UVA                                                              1
# Unión de Pueblos y Organizaciones del Estado de...                      0
# Zetas Vieja Escuela                                                     0
#
# grupo                                               Comandante Coronavirus  \
# grupo
# ACME                                                                     0
# Banda de El Perro                                                        0
# CJNG Comando la Mancha                                                   0
# Caballeros Templarios                                                    0
# Comandante Coronavirus                                                   0
# ...                                                                    ...
# Tláhuac-Barbas                                                           0
# Tropa del Infierno                                                       0
# U o la UVA                                                               0
# Unión de Pueblos y Organizaciones del Estado de...                       0
# Zetas Vieja Escuela                                                      1
#
# grupo                                               Cártel Independiente de Acapulco  \
# grupo
# ACME                                                                               0
# Banda de El Perro                                                                  0
# CJNG Comando la Mancha                                                             0
# Caballeros Templarios                                                              0
# Comandante Coronavirus                                                             0
# ...                                                                              ...
# Tláhuac-Barbas                                                                     0
# Tropa del Infierno                                                                 0
# U o la UVA                                                                         0
# Unión de Pueblos y Organizaciones del Estado de...                                 1
# Zetas Vieja Escuela                                                                0
#
# grupo                                               Cártel Jalisco Nueva Generación (CJNG)  \
# grupo
# ACME                                                                                     1
# Banda de El Perro                                                                        1
# CJNG Comando la Mancha                                                                   1
# Caballeros Templarios                                                                    1
# Comandante Coronavirus                                                                   1
# ...                                                                                    ...
# Tláhuac-Barbas                                                                           1
# Tropa del Infierno                                                                       1
# U o la UVA                                                                               1
# Unión de Pueblos y Organizaciones del Estado de...                                       1
# Zetas Vieja Escuela                                                                      1
#
# grupo                                               Cártel Los Epitacio  \
# grupo
# ACME                                                                  0
# Banda de El Perro                                                     0
# CJNG Comando la Mancha                                                0
# Caballeros Templarios                                                 0
# Comandante Coronavirus                                                0
# ...                                                                 ...
# Tláhuac-Barbas                                                        0
# Tropa del Infierno                                                    0
# U o la UVA                                                            0
# Unión de Pueblos y Organizaciones del Estado de...                    0
# Zetas Vieja Escuela                                                   0
#
# grupo                                               Cártel Nueva Plaza  \
# grupo
# ACME                                                                 0
# Banda de El Perro                                                    0
# CJNG Comando la Mancha                                               0
# Caballeros Templarios                                                0
# Comandante Coronavirus                                               0
# ...                                                                ...
# Tláhuac-Barbas                                                       0
# Tropa del Infierno                                                   0
# U o la UVA                                                           0
# Unión de Pueblos y Organizaciones del Estado de...                   0
# Zetas Vieja Escuela                                                  0
#
# grupo                                               Cártel Pura Gente Nueva  \
# grupo
# ACME                                                                      0
# Banda de El Perro                                                         0
# CJNG Comando la Mancha                                                    0
# Caballeros Templarios                                                     0
# Comandante Coronavirus                                                    0
# ...                                                                     ...
# Tláhuac-Barbas                                                            0
# Tropa del Infierno                                                        0
# U o la UVA                                                                0
# Unión de Pueblos y Organizaciones del Estado de...                        0
# Zetas Vieja Escuela                                                       0
#
# grupo                                               ...  Pedro Aviles Salazar  \
# grupo                                               ...
# ACME                                                ...                     0
# Banda de El Perro                                   ...                     0
# CJNG Comando la Mancha                              ...                     0
# Caballeros Templarios                               ...                     0
# Comandante Coronavirus                              ...                     0
# ...                                                 ...                   ...
# Tláhuac-Barbas                                      ...                     0
# Tropa del Infierno                                  ...                     0
# U o la UVA                                          ...                     0
# Unión de Pueblos y Organizaciones del Estado de...  ...                     1
# Zetas Vieja Escuela                                 ...                     0
#
# grupo                                               Robles  Sangre Nueva Zeta  \
# grupo
# ACME                                                     1                  0
# Banda de El Perro                                        1                  0
# CJNG Comando la Mancha                                   0                  0
# Caballeros Templarios                                    1                  0
# Comandante Coronavirus                                   0                  0
# ...                                                    ...                ...
# Tláhuac-Barbas                                           1                  0
# Tropa del Infierno                                       0                  0
# U o la UVA                                               1                  0
# Unión de Pueblos y Organizaciones del Estado de...       0                  0
# Zetas Vieja Escuela                                      0                  1
#
# grupo                                               Sindicato Libertad  \
# grupo
# ACME                                                                 1
# Banda de El Perro                                                    1
# CJNG Comando la Mancha                                               0
# Caballeros Templarios                                                1
# Comandante Coronavirus                                               0
# ...                                                                ...
# Tláhuac-Barbas                                                       1
# Tropa del Infierno                                                   0
# U o la UVA                                                           1
# Unión de Pueblos y Organizaciones del Estado de...                   0
# Zetas Vieja Escuela                                                  0
#
# grupo                                               Tercera Acción Destructiva (3AD)  \
# grupo
# ACME                                                                               1
# Banda de El Perro                                                                  1
# CJNG Comando la Mancha                                                             0
# Caballeros Templarios                                                              1
# Comandante Coronavirus                                                             0
# ...                                                                              ...
# Tláhuac-Barbas                                                                     1
# Tropa del Infierno                                                                 0
# U o la UVA                                                                         1
# Unión de Pueblos y Organizaciones del Estado de...                                 0
# Zetas Vieja Escuela                                                                0
#
# grupo                                               Tláhuac-Barbas  \
# grupo
# ACME                                                             1
# Banda de El Perro                                                1
# CJNG Comando la Mancha                                           0
# Caballeros Templarios                                            1
# Comandante Coronavirus                                           0
# ...                                                            ...
# Tláhuac-Barbas                                                   0
# Tropa del Infierno                                               0
# U o la UVA                                                       1
# Unión de Pueblos y Organizaciones del Estado de...               0
# Zetas Vieja Escuela                                              0
#
# grupo                                               Tropa del Infierno  \
# grupo
# ACME                                                                 0
# Banda de El Perro                                                    0
# CJNG Comando la Mancha                                               0
# Caballeros Templarios                                                0
# Comandante Coronavirus                                               0
# ...                                                                ...
# Tláhuac-Barbas                                                       0
# Tropa del Infierno                                                   0
# U o la UVA                                                           0
# Unión de Pueblos y Organizaciones del Estado de...                   0
# Zetas Vieja Escuela                                                  1
#
# grupo                                               U o la UVA  \
# grupo
# ACME                                                         1
# Banda de El Perro                                            1
# CJNG Comando la Mancha                                       0
# Caballeros Templarios                                        1
# Comandante Coronavirus                                       0
# ...                                                        ...
# Tláhuac-Barbas                                               1
# Tropa del Infierno                                           0
# U o la UVA                                                   0
# Unión de Pueblos y Organizaciones del Estado de...           0
# Zetas Vieja Escuela                                          0
#
# grupo                                               Unión de Pueblos y Organizaciones del Estado de Guerrero (UPOEG)   \
# grupo
# ACME                                                                                                0
# Banda de El Perro                                                                                   0
# CJNG Comando la Mancha                                                                              0
# Caballeros Templarios                                                                               0
# Comandante Coronavirus                                                                              0
# ...                                                                                               ...
# Tláhuac-Barbas                                                                                      0
# Tropa del Infierno                                                                                  0
# U o la UVA                                                                                          0
# Unión de Pueblos y Organizaciones del Estado de...                                                  0
# Zetas Vieja Escuela                                                                                 0
#
# grupo                                               Zetas Vieja Escuela
# grupo
# ACME                                                                  0
# Banda de El Perro                                                     0
# CJNG Comando la Mancha                                                0
# Caballeros Templarios                                                 0
# Comandante Coronavirus                                                1
# ...                                                                 ...
# Tláhuac-Barbas                                                        0
# Tropa del Infierno                                                    1
# U o la UVA                                                            0
# Unión de Pueblos y Organizaciones del Estado de...                    0
# Zetas Vieja Escuela                                                   0
#
# [150 rows x 150 columns]
